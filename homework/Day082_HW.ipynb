# %% [markdown]
# ## Work
# 1. 請比較使用不同層數以及不同 Dropout rate 對訓練的效果
# 2. 將 optimizer 改成使用 Adam 並加上適當的 dropout rate 檢視結果

# %%
import os
import keras
import itertools
from keras.layers import Dropout
import matplotlib.pyplot as plt
# %matplotlib inline

# Disable GPU
os.environ["CUDA_VISIBLE_DEVICES"] = ""

# %%
train, test = keras.datasets.cifar10.load_data()

# %%
## 資料前處理
def preproc_x(x, flatten=True):
    x = x / 255.
    if flatten:
        x = x.reshape((len(x), -1))
    return x

def preproc_y(y, num_classes=10):
    if y.shape[-1] == 1:
        y = keras.utils.to_categorical(y, num_classes)
    return y

# %%
x_train, y_train = train
x_test, y_test = test

# Preproc the inputs
x_train = preproc_x(x_train)
x_test = preproc_x(x_test)

# Preprc the outputs
y_train = preproc_y(y_train)
y_test = preproc_y(y_test)

# %%
def build_mlp(input_shape, output_units=10, num_neurons=[512, 256, 128], drop_ratio=0.5):
    input_layer = keras.layers.Input(input_shape)
    
    for i, n_units in enumerate(num_neurons):
        if i == 0:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(input_layer)
        else:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(x)
            x = Dropout(drop_ratio)(x)
    
    out = keras.layers.Dense(units=output_units, activation="softmax", name="output")(x)
    
    model = keras.models.Model(inputs=[input_layer], outputs=[out])
    return model

# %%
"""Code Here
設定超參數
"""
LEARNING_RATE = 1e-3
EPOCHS = 10
BATCH_SIZE = 256
MOMEMTUM = 0.95
DROPOUT_EXP = [0.25, 0.4, 0.55, 0.7, 0.85]

# %%
results = {}
"""Code Here
撰寫訓練流程並將結果用 dictionary 紀錄
"""
for drop_ratio in DROPOUT_EXP:
    keras.backend.clear_session()
    print('Experiment with drop_ratio:{:.2f}'.format(drop_ratio))
    model = build_mlp(input_shape = x_train.shape[1:], output_units = 10, num_neurons = [512, 256, 128], drop_ratio = drop_ratio)
    model.summary()
    optimizer = keras.optimizers.Adam(lr=LEARNING_RATE)
    model.compile(loss = 'categorical_crossentropy', metrics = ['accuracy'], optimizer = optimizer)
    
    model.fit(x_train, y_train, 
              epochs = EPOCHS, 
              batch_size = BATCH_SIZE, 
              validation_data = (x_test, y_test),
              shuffle = True)
    
    # Collect results
    train_loss = model.history.history["loss"]
    valid_loss = model.history.history["val_loss"]
    train_acc = model.history.history["accuracy"]
    valid_acc = model.history.history["val_accuracy"]
    
    exp_name_tag = "exp-l1-%s" % str(drop_ratio)
    results[exp_name_tag] = {'train-loss': train_loss,
                             'valid-loss': valid_loss,
                             'train-acc': train_acc,
                             'valid-acc': valid_acc}
    
    plt.plot(range(len(train_loss)), train_loss, label="train loss")
    plt.plot(range(len(valid_loss)), valid_loss, label="valid loss")
    plt.legend()
    plt.title("Loss")
    plt.show()
    
    plt.plot(range(len(train_acc)), train_acc, label="train accuracy")
    plt.plot(range(len(valid_acc)), valid_acc, label="valid accuracy")
    plt.legend()
    plt.title("Accuracy")
    plt.show()
# Out:
# Experiment with drop_ratio:0.25
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,738,890
# Trainable params: 1,738,890
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/10
# 50000/50000 [==============================] - 6s 110us/step - loss: 2.0370 - accuracy: 0.2490 - val_loss: 1.8412 - val_accuracy: 0.3409
# Epoch 2/10
# 50000/50000 [==============================] - 5s 107us/step - loss: 1.8156 - accuracy: 0.3458 - val_loss: 1.7345 - val_accuracy: 0.3885
# Epoch 3/10
# 50000/50000 [==============================] - 5s 108us/step - loss: 1.7313 - accuracy: 0.3814 - val_loss: 1.6695 - val_accuracy: 0.4007
# Epoch 4/10
# 50000/50000 [==============================] - 5s 106us/step - loss: 1.6636 - accuracy: 0.4058 - val_loss: 1.5810 - val_accuracy: 0.4289
# Epoch 5/10
# 50000/50000 [==============================] - 5s 106us/step - loss: 1.6108 - accuracy: 0.4235 - val_loss: 1.5614 - val_accuracy: 0.4475
# Epoch 6/10
# 50000/50000 [==============================] - 5s 106us/step - loss: 1.5718 - accuracy: 0.4374 - val_loss: 1.5253 - val_accuracy: 0.4623
# Epoch 7/10
# 50000/50000 [==============================] - 5s 107us/step - loss: 1.5428 - accuracy: 0.4508 - val_loss: 1.5213 - val_accuracy: 0.4482
# Epoch 8/10
# 50000/50000 [==============================] - 5s 106us/step - loss: 1.5209 - accuracy: 0.4584 - val_loss: 1.4907 - val_accuracy: 0.4652
# Epoch 9/10
# 50000/50000 [==============================] - 5s 105us/step - loss: 1.4932 - accuracy: 0.4653 - val_loss: 1.4579 - val_accuracy: 0.4821
# Epoch 10/10
# 50000/50000 [==============================] - 5s 106us/step - loss: 1.4705 - accuracy: 0.4740 - val_loss: 1.4770 - val_accuracy: 0.4726
# Experiment with drop_ratio:0.40
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,738,890
# Trainable params: 1,738,890
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/10
# 50000/50000 [==============================] - 5s 109us/step - loss: 2.0876 - accuracy: 0.2200 - val_loss: 1.8666 - val_accuracy: 0.3286
# Epoch 2/10
# 50000/50000 [==============================] - 5s 106us/step - loss: 1.8670 - accuracy: 0.3247 - val_loss: 1.7476 - val_accuracy: 0.3686
# Epoch 3/10
# 50000/50000 [==============================] - 5s 105us/step - loss: 1.7779 - accuracy: 0.3631 - val_loss: 1.6688 - val_accuracy: 0.4041
# Epoch 4/10
# 50000/50000 [==============================] - 5s 106us/step - loss: 1.7174 - accuracy: 0.3866 - val_loss: 1.6762 - val_accuracy: 0.3872
# Epoch 5/10
# 50000/50000 [==============================] - 5s 106us/step - loss: 1.6675 - accuracy: 0.4044 - val_loss: 1.5821 - val_accuracy: 0.4379
# Epoch 6/10
# 50000/50000 [==============================] - 5s 106us/step - loss: 1.6320 - accuracy: 0.4205 - val_loss: 1.5489 - val_accuracy: 0.4524
# Epoch 7/10
# 50000/50000 [==============================] - 5s 105us/step - loss: 1.5953 - accuracy: 0.4346 - val_loss: 1.5612 - val_accuracy: 0.4450
# Epoch 8/10
# 50000/50000 [==============================] - 5s 106us/step - loss: 1.5789 - accuracy: 0.4368 - val_loss: 1.5517 - val_accuracy: 0.4435
# Epoch 9/10
# 50000/50000 [==============================] - 5s 108us/step - loss: 1.5564 - accuracy: 0.4449 - val_loss: 1.5165 - val_accuracy: 0.4584
# Epoch 10/10
# 50000/50000 [==============================] - 6s 117us/step - loss: 1.5311 - accuracy: 0.4540 - val_loss: 1.5024 - val_accuracy: 0.4657
# Experiment with drop_ratio:0.55
# WARNING:tensorflow:Large dropout rate: 0.55 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# WARNING:tensorflow:Large dropout rate: 0.55 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,738,890
# Trainable params: 1,738,890
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/10
# 50000/50000 [==============================] - 6s 116us/step - loss: 2.1739 - accuracy: 0.1818 - val_loss: 1.9527 - val_accuracy: 0.2820
# Epoch 2/10
# 50000/50000 [==============================] - 6s 112us/step - loss: 1.9616 - accuracy: 0.2815 - val_loss: 1.8222 - val_accuracy: 0.3489
# Epoch 3/10
# 50000/50000 [==============================] - 6s 114us/step - loss: 1.8616 - accuracy: 0.3262 - val_loss: 1.7567 - val_accuracy: 0.3664
# Epoch 4/10
# 50000/50000 [==============================] - 6s 113us/step - loss: 1.7971 - accuracy: 0.3550 - val_loss: 1.6902 - val_accuracy: 0.3953
# Epoch 5/10
# 50000/50000 [==============================] - 5s 109us/step - loss: 1.7528 - accuracy: 0.3723 - val_loss: 1.7207 - val_accuracy: 0.3836
# Epoch 6/10
# 50000/50000 [==============================] - 5s 109us/step - loss: 1.7171 - accuracy: 0.3880 - val_loss: 1.6357 - val_accuracy: 0.4125
# Epoch 7/10
# 50000/50000 [==============================] - 5s 109us/step - loss: 1.6810 - accuracy: 0.4005 - val_loss: 1.5957 - val_accuracy: 0.4298
# Epoch 8/10
# 50000/50000 [==============================] - 5s 108us/step - loss: 1.6616 - accuracy: 0.4095 - val_loss: 1.5677 - val_accuracy: 0.4397
# Epoch 9/10
# 50000/50000 [==============================] - 5s 108us/step - loss: 1.6392 - accuracy: 0.4180 - val_loss: 1.5632 - val_accuracy: 0.4379
# Epoch 10/10
# 50000/50000 [==============================] - 5s 108us/step - loss: 1.6184 - accuracy: 0.4227 - val_loss: 1.5651 - val_accuracy: 0.4369
# Experiment with drop_ratio:0.70
# WARNING:tensorflow:Large dropout rate: 0.7 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# WARNING:tensorflow:Large dropout rate: 0.7 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,738,890
# Trainable params: 1,738,890
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/10
# 50000/50000 [==============================] - 5s 109us/step - loss: 2.3035 - accuracy: 0.1159 - val_loss: 2.2686 - val_accuracy: 0.1642
# Epoch 2/10
# 50000/50000 [==============================] - 5s 106us/step - loss: 2.2576 - accuracy: 0.1328 - val_loss: 2.1839 - val_accuracy: 0.1885
# Epoch 3/10
# 50000/50000 [==============================] - 5s 106us/step - loss: 2.1894 - accuracy: 0.1590 - val_loss: 2.1359 - val_accuracy: 0.2058
# Epoch 4/10
# 50000/50000 [==============================] - 5s 105us/step - loss: 2.1223 - accuracy: 0.1814 - val_loss: 2.0618 - val_accuracy: 0.2312
# Epoch 5/10
# 50000/50000 [==============================] - 5s 105us/step - loss: 2.0429 - accuracy: 0.2151 - val_loss: 1.9626 - val_accuracy: 0.2515
# Epoch 6/10
# 50000/50000 [==============================] - 5s 105us/step - loss: 1.9781 - accuracy: 0.2501 - val_loss: 1.8903 - val_accuracy: 0.2873
# Epoch 7/10
# 50000/50000 [==============================] - 5s 105us/step - loss: 1.9318 - accuracy: 0.2810 - val_loss: 1.8776 - val_accuracy: 0.2979
# Epoch 8/10
# 50000/50000 [==============================] - 5s 105us/step - loss: 1.8902 - accuracy: 0.3055 - val_loss: 1.7868 - val_accuracy: 0.3528
# Epoch 9/10
# 50000/50000 [==============================] - 5s 105us/step - loss: 1.8548 - accuracy: 0.3223 - val_loss: 1.7533 - val_accuracy: 0.3674
# Epoch 10/10
# 50000/50000 [==============================] - 5s 105us/step - loss: 1.8323 - accuracy: 0.3329 - val_loss: 1.7476 - val_accuracy: 0.3722
# Experiment with drop_ratio:0.85
# WARNING:tensorflow:Large dropout rate: 0.85 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,738,890
# Trainable params: 1,738,890
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/10
# 50000/50000 [==============================] - 5s 108us/step - loss: 2.3468 - accuracy: 0.1002 - val_loss: 2.3029 - val_accuracy: 0.0999
# Epoch 2/10
# 50000/50000 [==============================] - 5s 105us/step - loss: 2.3027 - accuracy: 0.0998 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 3/10
# 50000/50000 [==============================] - 5s 105us/step - loss: 2.3027 - accuracy: 0.0978 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 4/10
# 50000/50000 [==============================] - 5s 106us/step - loss: 2.3027 - accuracy: 0.0986 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 5/10
# 50000/50000 [==============================] - 5s 106us/step - loss: 2.3138 - accuracy: 0.0969 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 6/10
# 50000/50000 [==============================] - 5s 105us/step - loss: 2.3066 - accuracy: 0.1000 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 7/10
# 50000/50000 [==============================] - 5s 106us/step - loss: 2.3027 - accuracy: 0.0975 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 8/10
# 50000/50000 [==============================] - 5s 105us/step - loss: 2.3027 - accuracy: 0.0969 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 9/10
# 50000/50000 [==============================] - 5s 105us/step - loss: 2.3027 - accuracy: 0.0981 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 10/10
# 50000/50000 [==============================] - 5s 105us/step - loss: 2.3027 - accuracy: 0.0973 - val_loss: 2.3026 - val_accuracy: 0.1000
