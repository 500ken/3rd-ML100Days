# %% [markdown]
# ## Work
# 1. 試比較 save_best_only 與否的差異
# 2. 請僅存入將 save_weights_only 設定為 True, 並嘗試 reset ipynb 並將模型與權重重新建回並預測 x_test

# %%
import os
import keras

# Disable GPU
os.environ["CUDA_VISIBLE_DEVICES"] = ""
# Out:
# Using TensorFlow backend.

# %%
train, test = keras.datasets.cifar10.load_data()

# %%
## 資料前處理
def preproc_x(x, flatten=True):
    x = x / 255.
    if flatten:
        x = x.reshape((len(x), -1))
    return x

def preproc_y(y, num_classes=10):
    if y.shape[-1] == 1:
        y = keras.utils.to_categorical(y, num_classes)
    return y

# %%
x_train, y_train = train
x_test, y_test = test

# Preproc the inputs
x_train = preproc_x(x_train)
x_test = preproc_x(x_test)

# Preprc the outputs
y_train = preproc_y(y_train)
y_test = preproc_y(y_test)

# %%
from keras.layers import BatchNormalization

def build_mlp(input_shape, output_units=10, num_neurons=[512, 256, 128]):
    input_layer = keras.layers.Input(input_shape)
    
    for i, n_units in enumerate(num_neurons):
        if i == 0:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(input_layer)
            x = BatchNormalization()(x)
        else:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(x)
            x = BatchNormalization()(x)
    
    out = keras.layers.Dense(units=output_units, activation="softmax", name="output")(x)
    
    model = keras.models.Model(inputs=[input_layer], outputs=[out])
    return model

# %%
"""Code Here
設定超參數
"""
LEARNING_RATE = 1e-3
EPOCHS = 20
BATCH_SIZE = 1024
MOMENTUM = 0.95

# %%
# 載入 Callbacks
"""Code Here
設定 callbacks: model checkpoint
"""
from keras.callbacks import ModelCheckpoint

results = {}
"""Code Here
撰寫你的訓練流程並將結果用 dictionary 紀錄
"""
import matplotlib.pyplot as plt
# %matplotlib inline

for save_best_only in [True, False]:
    model_ckpt = ModelCheckpoint(filepath="./tmp.h5", 
                             monitor="val_loss", 
                             save_best_only=save_best_only)
    model = build_mlp(input_shape=x_train.shape[1:])
    model.summary()
    optimizer = keras.optimizers.SGD(lr=LEARNING_RATE, nesterov=True, momentum=MOMENTUM)
    model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizer)

    model.fit(x_train, y_train, 
              epochs=EPOCHS, 
              batch_size=BATCH_SIZE, 
              validation_data=(x_test, y_test), 
              shuffle=True,
              callbacks=[model_ckpt]
             )
    # Collect results    
    train_loss = model.history.history["loss"]
    valid_loss = model.history.history["val_loss"]
    train_acc = model.history.history["accuracy"]
    valid_acc = model.history.history["val_accuracy"]
    name_tag = 'save_best_only: %s' % str(save_best_only)
    results[name_tag] = {'train-loss': train_loss,
                         'valid-loss': valid_loss,
                         'train-acc': train_acc,
                         'valid-acc': valid_acc}
    
    # Load back
    model = keras.models.load_model("./tmp.h5")
    loss_loadback, acc_loadback = model.evaluate(x_test, y_test)
    print("loss_loadback", loss_loadback)
    print("acc_loadback", acc_loadback)



    plt.plot(range(len(train_loss)), train_loss, label="train loss")
    plt.plot(range(len(valid_loss)), valid_loss, label="valid loss")
    plt.hlines(y=loss_loadback, xmin=0, xmax=len(train_loss), colors='r', linestyles='--')
    plt.legend()
    plt.title("Loss")
    plt.show()

    plt.plot(range(len(train_acc)), train_acc, label="train accuracy")
    plt.plot(range(len(valid_acc)), valid_acc, label="valid accuracy")
    plt.hlines(y=acc_loadback, xmin=0, xmax=len(train_loss), colors='r', linestyles='--')
    plt.legend()
    plt.title("Accuracy")
    plt.show()
# Out:
# Model: "model_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_16 (Batc (None, 512)               2048
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_17 (Batc (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_18 (Batc (None, 128)               512
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/20
# 50000/50000 [==============================] - 4s 79us/step - loss: 2.2238 - accuracy: 0.2662 - val_loss: 2.1325 - val_accuracy: 0.2305
# Epoch 2/20
# 50000/50000 [==============================] - 4s 70us/step - loss: 1.7497 - accuracy: 0.3911 - val_loss: 1.9487 - val_accuracy: 0.3127
# Epoch 3/20
# 50000/50000 [==============================] - 4s 72us/step - loss: 1.6312 - accuracy: 0.4282 - val_loss: 1.8155 - val_accuracy: 0.3716
# Epoch 4/20
# 50000/50000 [==============================] - 4s 81us/step - loss: 1.5614 - accuracy: 0.4552 - val_loss: 1.7204 - val_accuracy: 0.4080
# Epoch 5/20
# 50000/50000 [==============================] - 4s 71us/step - loss: 1.5096 - accuracy: 0.4724 - val_loss: 1.6380 - val_accuracy: 0.4339
# Epoch 6/20
# 50000/50000 [==============================] - 4s 78us/step - loss: 1.4634 - accuracy: 0.4902 - val_loss: 1.5899 - val_accuracy: 0.4429
# Epoch 7/20
# 50000/50000 [==============================] - 4s 74us/step - loss: 1.4251 - accuracy: 0.5027 - val_loss: 1.5540 - val_accuracy: 0.4579
# Epoch 8/20
# 50000/50000 [==============================] - 4s 71us/step - loss: 1.3875 - accuracy: 0.5170 - val_loss: 1.5401 - val_accuracy: 0.4593
# Epoch 9/20
# 50000/50000 [==============================] - 4s 70us/step - loss: 1.3570 - accuracy: 0.5275 - val_loss: 1.5106 - val_accuracy: 0.4586
# Epoch 10/20
# 50000/50000 [==============================] - 4s 70us/step - loss: 1.3245 - accuracy: 0.5396 - val_loss: 1.4925 - val_accuracy: 0.4688
# Epoch 11/20
# 50000/50000 [==============================] - 4s 70us/step - loss: 1.2969 - accuracy: 0.5481 - val_loss: 1.4888 - val_accuracy: 0.4682
# Epoch 12/20
# 50000/50000 [==============================] - 4s 70us/step - loss: 1.2698 - accuracy: 0.5583 - val_loss: 1.4774 - val_accuracy: 0.4759
# Epoch 13/20
# 50000/50000 [==============================] - 4s 70us/step - loss: 1.2426 - accuracy: 0.5700 - val_loss: 1.4661 - val_accuracy: 0.4795
# Epoch 14/20
# 50000/50000 [==============================] - 4s 70us/step - loss: 1.2174 - accuracy: 0.5780 - val_loss: 1.4756 - val_accuracy: 0.4760
# Epoch 15/20
# 50000/50000 [==============================] - 4s 70us/step - loss: 1.1922 - accuracy: 0.5869 - val_loss: 1.4516 - val_accuracy: 0.4867
# Epoch 16/20
# 50000/50000 [==============================] - 4s 71us/step - loss: 1.1679 - accuracy: 0.5981 - val_loss: 1.4582 - val_accuracy: 0.4897
# Epoch 17/20
# 50000/50000 [==============================] - 4s 70us/step - loss: 1.1467 - accuracy: 0.6044 - val_loss: 1.4516 - val_accuracy: 0.4860
# Epoch 18/20
# 50000/50000 [==============================] - 4s 71us/step - loss: 1.1239 - accuracy: 0.6148 - val_loss: 1.4498 - val_accuracy: 0.4909
# Epoch 19/20
# 50000/50000 [==============================] - 3s 70us/step - loss: 1.1027 - accuracy: 0.6208 - val_loss: 1.4658 - val_accuracy: 0.4879
# Epoch 20/20
# 50000/50000 [==============================] - 4s 70us/step - loss: 1.0812 - accuracy: 0.6298 - val_loss: 1.4473 - val_accuracy: 0.4929
# 10000/10000 [==============================] - 1s 74us/step
# loss_loadback 1.4472516439437866
# acc_loadback 0.492900013923645
# Model: "model_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_7 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_19 (Batc (None, 512)               2048
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_20 (Batc (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_21 (Batc (None, 128)               512
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/20
# 50000/50000 [==============================] - 4s 79us/step - loss: 2.2400 - accuracy: 0.2676 - val_loss: 2.1269 - val_accuracy: 0.1991
# Epoch 2/20
# 50000/50000 [==============================] - 4s 71us/step - loss: 1.7513 - accuracy: 0.3915 - val_loss: 1.9907 - val_accuracy: 0.2609
# Epoch 3/20
# 50000/50000 [==============================] - 4s 70us/step - loss: 1.6237 - accuracy: 0.4335 - val_loss: 1.8209 - val_accuracy: 0.3618
# Epoch 4/20
# 50000/50000 [==============================] - 4s 71us/step - loss: 1.5487 - accuracy: 0.4591 - val_loss: 1.7314 - val_accuracy: 0.3941
# Epoch 5/20
# 50000/50000 [==============================] - 4s 71us/step - loss: 1.4928 - accuracy: 0.4812 - val_loss: 1.6356 - val_accuracy: 0.4256
# Epoch 6/20
# 50000/50000 [==============================] - 4s 70us/step - loss: 1.4482 - accuracy: 0.4966 - val_loss: 1.5922 - val_accuracy: 0.4453
# Epoch 7/20
# 50000/50000 [==============================] - 4s 70us/step - loss: 1.4079 - accuracy: 0.5087 - val_loss: 1.5557 - val_accuracy: 0.4475
# Epoch 8/20
# 50000/50000 [==============================] - 3s 70us/step - loss: 1.3748 - accuracy: 0.5231 - val_loss: 1.5341 - val_accuracy: 0.4573
# Epoch 9/20
# 50000/50000 [==============================] - 4s 70us/step - loss: 1.3415 - accuracy: 0.5363 - val_loss: 1.5088 - val_accuracy: 0.4666
# Epoch 10/20
# 50000/50000 [==============================] - 4s 71us/step - loss: 1.3141 - accuracy: 0.5462 - val_loss: 1.5078 - val_accuracy: 0.4658
# Epoch 11/20
# 50000/50000 [==============================] - 4s 70us/step - loss: 1.2866 - accuracy: 0.5535 - val_loss: 1.4881 - val_accuracy: 0.4762
# Epoch 12/20
# 50000/50000 [==============================] - 4s 71us/step - loss: 1.2589 - accuracy: 0.5658 - val_loss: 1.4939 - val_accuracy: 0.4721
# Epoch 13/20
# 50000/50000 [==============================] - 4s 71us/step - loss: 1.2326 - accuracy: 0.5748 - val_loss: 1.4808 - val_accuracy: 0.4789
# Epoch 14/20
# 50000/50000 [==============================] - 4s 70us/step - loss: 1.2070 - accuracy: 0.5832 - val_loss: 1.4814 - val_accuracy: 0.4780
# Epoch 15/20
# 50000/50000 [==============================] - 3s 69us/step - loss: 1.1822 - accuracy: 0.5926 - val_loss: 1.4841 - val_accuracy: 0.4765
# Epoch 16/20
# 50000/50000 [==============================] - 4s 70us/step - loss: 1.1602 - accuracy: 0.6009 - val_loss: 1.4874 - val_accuracy: 0.4712
# Epoch 17/20
# 50000/50000 [==============================] - 3s 69us/step - loss: 1.1383 - accuracy: 0.6104 - val_loss: 1.4655 - val_accuracy: 0.4870
# Epoch 18/20
# 50000/50000 [==============================] - 3s 70us/step - loss: 1.1131 - accuracy: 0.6184 - val_loss: 1.4753 - val_accuracy: 0.4819
# Epoch 19/20
# 50000/50000 [==============================] - 3s 70us/step - loss: 1.0933 - accuracy: 0.6253 - val_loss: 1.4560 - val_accuracy: 0.4900
# Epoch 20/20
# 50000/50000 [==============================] - 3s 69us/step - loss: 1.0711 - accuracy: 0.6345 - val_loss: 1.4687 - val_accuracy: 0.4879
# 10000/10000 [==============================] - 1s 72us/step
# loss_loadback 1.4687107078552246
# acc_loadback 0.4878999888896942
